# %%
from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("birdsql/bird23-train-filtered")

# %%
# Explore the dataset structure
print("Dataset info:")
print(ds)
print("\nDataset features:")
print(ds['train'].features)
print(f"\nNumber of training samples: {len(ds['train'])}")
# Out:
# Dataset info:
# DatasetDict({
#     train: Dataset({
#         features: ['db_id', 'question', 'evidence', 'SQL'],
#         num_rows: 6601
#     })
# })
#
# Dataset features:
# {'db_id': Value('string'), 'question': Value('string'), 'evidence': Value('string'), 'SQL': Value('string')}
#
# Number of training samples: 6601
